# %% [markdown]
# importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import cv2
import os

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.layers import Conv2D, MaxPool2D, Dropout, Dense, Flatten
from keras.models import Sequential, load_model

# %% [markdown]
# Image Processing

# %%
data=[]
labels=[]
classes=43
# cur_dir=os.getcwd()

for i in range(classes):
    path = os.path.join('../input/gtsrb-german-traffic-sign/Train',str(i))
    images = os.listdir(path)
    
    for a in images:
        try:
            image = Image.open(path + '//'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            #sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
            
        except:
            print("Error loading image")

# %%
# converting list to numpy arrays
    
data=np.array(data)
labels=np.array(labels)

# %%
print('data_shape {}, labels_shape  {}' .format(data.shape,labels.shape))
# Out:
# data_shape (39209, 30, 30, 3), labels_shape  (39209,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data,labels,test_size=0.2,random_state=42)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (31367, 30, 30, 3) (7842, 30, 30, 3)

# %%
y_train=to_categorical(y_train,43)
y_test=to_categorical(y_test,43)

# %%
X_train.shape[1:]
# Out:
# (30, 30, 3)

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

# %%
import keras

# %%
# es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
monitor=keras.callbacks.EarlyStopping(monitor='val_loss',
                              min_delta=0,
                              patience=5,
                              verbose=0, mode='auto')

# %%
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(lr=0.0001), metrics=['accuracy'])

# %%
# epochs = 10
history = model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_test, y_test),callbacks=[monitor])
# Out:
# Epoch 1/100
# 981/981 [==============================] - 4s 5ms/step - loss: 3.1873 - accuracy: 0.2952 - val_loss: 1.4889 - val_accuracy: 0.6446
# Epoch 2/100
# 981/981 [==============================] - 5s 5ms/step - loss: 1.5134 - accuracy: 0.6052 - val_loss: 0.7938 - val_accuracy: 0.8369
# Epoch 3/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.9019 - accuracy: 0.7535 - val_loss: 0.3927 - val_accuracy: 0.9232
# Epoch 4/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.5918 - accuracy: 0.8405 - val_loss: 0.2426 - val_accuracy: 0.9458
# Epoch 5/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.4235 - accuracy: 0.8868 - val_loss: 0.1270 - val_accuracy: 0.9736
# Epoch 6/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.3214 - accuracy: 0.9156 - val_loss: 0.1000 - val_accuracy: 0.9786
# Epoch 7/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.2592 - accuracy: 0.9326 - val_loss: 0.0893 - val_accuracy: 0.9799
# Epoch 8/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2199 - accuracy: 0.9417 - val_loss: 0.0643 - val_accuracy: 0.9869
# Epoch 9/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1859 - accuracy: 0.9514 - val_loss: 0.0613 - val_accuracy: 0.9858
# Epoch 10/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.1661 - accuracy: 0.9564 - val_loss: 0.0506 - val_accuracy: 0.9899
# Epoch 11/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1502 - accuracy: 0.9620 - val_loss: 0.0451 - val_accuracy: 0.9897
# Epoch 12/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1295 - accuracy: 0.9668 - val_loss: 0.0492 - val_accuracy: 0.9909
# Epoch 13/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.1176 - accuracy: 0.9700 - val_loss: 0.0358 - val_accuracy: 0.9925
# Epoch 14/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1150 - accuracy: 0.9698 - val_loss: 0.0437 - val_accuracy: 0.9917
# Epoch 15/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.1016 - accuracy: 0.9745 - val_loss: 0.0296 - val_accuracy: 0.9938
# Epoch 16/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0964 - accuracy: 0.9756 - val_loss: 0.0310 - val_accuracy: 0.9936
# Epoch 17/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.0962 - accuracy: 0.9767 - val_loss: 0.0337 - val_accuracy: 0.9925
# Epoch 18/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.0880 - accuracy: 0.9774 - val_loss: 0.0265 - val_accuracy: 0.9950
# Epoch 19/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.0799 - accuracy: 0.9804 - val_loss: 0.0252 - val_accuracy: 0.9958
# Epoch 20/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.0838 - accuracy: 0.9792 - val_loss: 0.0293 - val_accuracy: 0.9944
# Epoch 21/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.0758 - accuracy: 0.9815 - val_loss: 0.0325 - val_accuracy: 0.9945
# Epoch 22/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.0742 - accuracy: 0.9810 - val_loss: 0.0281 - val_accuracy: 0.9958
# Epoch 23/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.0780 - accuracy: 0.9821 - val_loss: 0.0297 - val_accuracy: 0.9949
# Epoch 24/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0772 - accuracy: 0.9826 - val_loss: 0.0248 - val_accuracy: 0.9953
# Epoch 25/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0701 - accuracy: 0.9829 - val_loss: 0.0286 - val_accuracy: 0.9954
# Epoch 26/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.0681 - accuracy: 0.9835 - val_loss: 0.0323 - val_accuracy: 0.9940
# Epoch 27/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0635 - accuracy: 0.9850 - val_loss: 0.0307 - val_accuracy: 0.9962
# Epoch 28/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.0652 - accuracy: 0.9845 - val_loss: 0.0289 - val_accuracy: 0.9955
# Epoch 29/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.0658 - accuracy: 0.9850 - val_loss: 0.0413 - val_accuracy: 0.9943

# %%
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# from keras.models import load_model

# %%
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
def test_on_img(img):
    data=[]
    image = Image.open(img)
    image = image.resize((30,30))
    data.append(np.array(image))
    X_test=np.array(data)
    Y_pred = model.predict_classes(X_test)
    return image,Y_pred

# %%
plot,prediction = test_on_img('../input/gtsrb-german-traffic-sign/Test/00174.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# confusion_matrix(y_test,prediction)
# Out:
# Predicted traffic sign is:  Turn right ahead

# %%
from sklearn.metrics import accuracy_score

pred=model.predict(X_test)
prected_class=np.argmax(pred,axis=1)
expected_class=np.argmax(y_test,axis=1)

correct=accuracy_score(expected_class,prected_class)

print('Accuracy{}' .format(correct))
# Out:
# Accuracy0.9942616679418516
